# %%
import json

# %%
Record = {1001:{'Name' :'Rice           ,'Price':60    ,'Exp.date':'Jan22'    ,'Quantity':1000    ,'Discount':5 },
          1002:{'Name' :'Wheat       '  ,'Price':28    ,'Exp.date':'Jan22'    ,'Quantity':1000    ,'Discount':5 },
          1003:{'Name' :'Sugar       -' ,'Price':40    ,'Exp.date':'Dec21'    ,'Quantity':1000    ,'Discount':2 },
          1004:{'Name' :'salt       '   ,'Price':21    ,'Exp.date':'Feb22'    ,'Quantity':1000    ,'Discount':10 },
          1005:{'Name' :'maida          ,'Price':50    ,'Exp.date':'Nov21'    ,'Quantity':1000    ,'Discount':7 },
          1006:{'Name' :'Soyabean oil   ,'Price':2850  ,'Exp.date':'Mar22'    ,'Quantity':1500    ,'Discount':14 },
          1007:{'Name' :'coconut oil'   ,'Price':200   ,'Exp.date':'Dec22'    ,'Quantity':500     ,'Discount':5 },
          1008:{'Name' :'maggie'        ,'Price':100   ,'Exp.date':'Dec24'    ,'Quantity':500     ,'Discount':2 },
          1009:{'Name' :'SuparNirama    ,'Price':80    ,'Exp.date':'Dec25'    ,'Quantity':1000    ,'Discount':5 },
          1010:{'Name' :'Wheel Soap'    ,'Price':100   ,'Exp.date':'Feb22'    ,'Quantity':10      ,'Discount':10 },
          1011:{'Name' :'Rin powder'    ,'Price':160   ,'Exp.date':'Apr24'    ,'Quantity':1000    ,'Discount':4 },
          1012:{'Name' :'cynthol soap'  ,'Price':50    ,'Exp.date':'Mar22'    ,'Quantity':1       ,'Discount':8 },
          1013:{'Name' :'colgate'       ,'Price':90    ,'Exp.date':'Feb21 '   ,'Quantity':100     ,'Discount':8 },
          1014:{'Name' :'Ponds'         ,'Price':20    ,'Exp.date':'Jun25'    ,'Quantity':60      ,'Discount':6 },
          1015:{'Name' :'facewash'      ,'Price':145   ,'Exp.date':'Dec21'    ,'Quantity':200     ,'Discount':6 },
          1016:{'Name' :'Fair & lovely' ,'Price':15    ,'Exp.date':'Dec21'    ,'Quantity':25      ,'Discount':6 },
          1017:{'Name' :'Haldi 2kg'     ,'Price':390   ,'Exp.date':'Nov22'    ,'Quantity':2000    ,'Discount':15 },
          1018:{'Name' :'TEA 1kg'       ,'Price':370   ,'Exp.date':'Nov23'    ,'Quantity':1000    ,'Discount':20 },
          1019:{'Name' :'Dhana Powdwer' ,'Price':60    ,'Exp.date':'Dec26'    ,'Quantity':250     ,'Discount':18 },
          1020:{'Name' :'Everest Mas'   ,'Price':20    ,'Exp.date':'May22'    ,'Quantity':40      ,'Discount':22 },
          1021:{'Name' :'Coffee'        ,'Price':175   ,'Exp.date':'Dec25'    ,'Quantity':100     ,'Discount':20 },
          1022:{'Name' :'Sugar free tab','Price':250   ,'Exp.date':'Dec25'    ,'Quantity':100     ,'Discount':20 },
          1023:{'Name' :'Kishmish'      ,'Price':100   ,'Exp.date':'Dec24'    ,'Quantity':1000    ,'Discount':15 },
          1024:{'Name' :'vaticashampoo' ,'Price':20    ,'Exp.date':'Jan30'    ,'Quantity':20      ,'Discount':25 },
          1025:{'Name' :'Elayachi'      ,'Price':500   ,'Exp.date':'Jan35'    ,'Quantity':100     ,'Discount':25 },
          1026:{'Name' :'Sabudana'      ,'Price':80    ,'Exp.date':'Aug24'    ,'Quantity':1000    ,'Discount':18 },
          1027:{'Name' :'Amul Ghee'     ,'Price':280   ,'Exp.date':'Sept23'   ,'Quantity':500     ,'Discount':20 },
          1028:{'Name' :'burbon cookie' ,'Price':20    ,'Exp.date':'Oct24'    ,'Quantity':50      ,'Discount':9 },
          1029:{'Name' :'Toast'         ,'Price':50    ,'Exp.date':'Nov30'    ,'Quantity':1000    ,'Discount':15 },
          1030:{'Name' :'Peanuts'       ,'Price':140   ,'Exp.date':'Jan23'    ,'Quantity':1000    ,'Discount':30 }}
# Out:
#   File "<ipython-input-20-ed60d3f434e3>", line 1
#     Record = {1001:{'Name' :'Rice           ,'Price':60    ,'Exp.date':'Jan22'    ,'Quantity':1000    ,'Discount':5 },
#                                                   ^
# SyntaxError: invalid syntax

# %%
js
# Out:
# '{"1001": {"Name": "parle", "Price": 10, "Exp.date": "Jan22", "Quantity": 1000, "Discount": 5}, "1002": {"Name": "Parle-G", "Price": 50, "Exp.date": "Jan22", "Quantity": 2000, "Discount": 5}, "1003": {"Name": "Good-Day", "Price": 10, "Exp.date": "Dec21", "Quantity": 650, "Discount": 2}, "1004": {"Name": " Happy ", "Price": 20, "Exp.date": "Feb22", "Quantity": 700, "Discount": 10}, "1005": {"Name": "MarriGold", "Price": 10, "Exp.date": "Nov21", "Quantity": 666, "Discount": 7}, "1006": {"Name": "CreamBuis", "Price": 55, "Exp.date": "Mar22", "Quantity": 987, "Discount": 14}, "1007": {"Name": "Momsmajic", "Price": 60, "Exp.date": "Dec22", "Quantity": 546, "Discount": 5}, "1008": {"Name": "Shantabai", "Price": 10, "Exp.date": "Dec24", "Quantity": 100, "Discount": 2}, "1009": {"Name": "SuparNirama", "Price": 55, "Exp.date": "Dec25", "Quantity": 540, "Discount": 5}, "1010": {"Name": "Sargam Soap", "Price": 110, "Exp.date": "Feb22", "Quantity": 5555, "Discount": 10}, "1011": {"Name": "Rin", 
# ...

# %%
fd = open("Record.json",'w')

fd.write(js)

fd.close()

# %%
fd = open('Record.json','r')

txt=fd.read()

fd.close()

# %%
txt
# Out:
# '{"1001": {"Name": "parle", "Price": 10, "Exp.date": "Jan22", "Quantity": 1000, "Discount": 5}, "1002": {"Name": "Parle-G", "Price": 50, "Exp.date": "Jan22", "Quantity": 2000, "Discount": 5}, "1003": {"Name": "Good-Day", "Price": 10, "Exp.date": "Dec21", "Quantity": 650, "Discount": 2}, "1004": {"Name": " Happy ", "Price": 20, "Exp.date": "Feb22", "Quantity": 700, "Discount": 10}, "1005": {"Name": "MarriGold", "Price": 10, "Exp.date": "Nov21", "Quantity": 666, "Discount": 7}, "1006": {"Name": "CreamBuis", "Price": 55, "Exp.date": "Mar22", "Quantity": 987, "Discount": 14}, "1007": {"Name": "Momsmajic", "Price": 60, "Exp.date": "Dec22", "Quantity": 546, "Discount": 5}, "1008": {"Name": "Shantabai", "Price": 10, "Exp.date": "Dec24", "Quantity": 100, "Discount": 2}, "1009": {"Name": "SuparNirama", "Price": 55, "Exp.date": "Dec25", "Quantity": 540, "Discount": 5}, "1010": {"Name": "Sargam Soap", "Price": 110, "Exp.date": "Feb22", "Quantity": 5555, "Discount": 10}, "1011": {"Name": "Rin", 
# ...

# %%
product = json.loads(txt)

# %%
product
# Out:
# {'1001': {'Discount': 5,
#   'Exp.date': 'Jan22',
#   'Name': 'parle',
#   'Price': 10,
#   'Quantity': 1000},
#  '1002': {'Discount': 5,
#   'Exp.date': 'Jan22',
#   'Name': 'Parle-G',
#   'Price': 50,
#   'Quantity': 2000},
#  '1003': {'Discount': 2,
#   'Exp.date': 'Dec21',
#   'Name': 'Good-Day',
#   'Price': 10,
#   'Quantity': 650},
#  '1004': {'Discount': 10,
#   'Exp.date': 'Feb22',
#   'Name': ' Happy ',
#   'Price': 20,
#   'Quantity': 700},
#  '1005': {'Discount': 7,
#   'Exp.date': 'Nov21',
#   'Name': 'MarriGold',
#   'Price': 10,
#   'Quantity': 666},
#  '1006': {'Discount': 14,
#   'Exp.date': 'Mar22',
#   'Name': 'CreamBuis',
#   'Price': 55,
#   'Quantity': 987},
#  '1007': {'Discount': 5,
#   'Exp.date': 'Dec22',
#   'Name': 'Momsmajic',
#   'Price': 60,
#   'Quantity': 546},
#  '1008': {'Discount': 2,
#   'Exp.date': 'Dec24',
#   'Name': 'Shantabai',
#   'Price': 10,
#   'Quantity': 100},
#  '1009': {'Discount': 5,
#   'Exp.date': 'Dec25',
# ...

# %%
import time

# %%
print("*****WELCOME TO THE SHOP*****")

ui_name=input('Enter the User Name :')

print(product)

ui_prod = str(input("Enter the product ID :"))

ui_quan = int(input("Enter the Quantity :"))

if(ui_prod in product):
  print('Date and Time :',time.ctime())
  print('Name of custmer :',ui_name)
  print('Name of selected product ID :',product[ui_prod]['Name'])
  print('Price of selected product Id :',product[ui_prod]['Price'])
  print('*****CONGRATULATION YOU HAVE OWN DISCOUNT ON THIS PRODUCT*****')
  print('Discount :',product[ui_prod]['Discount'])
  print('*****PRINTING BILLING AMOUNT*****')
  gen_bill=(product[ui_prod]['Price']*ui_quan)-((product[ui_prod]['Price']*ui_quan)*product[ui_prod]['Discount'])/100
  print('Billing Amount :',gen_bill)
  print("Thank you for visting our shop")
  

  product[ui_prod]['Quantuty']=product[ui_prod]['Quantity']-ui_quan
# Out:
# *****WELCOME TO THE SHOP*****
# Enter the User Name :Roshan warade
# ...

# %%
import random

# %%
trans_ID = random.uniform(1 , 100000)

# %%
Transaction={'trans_ID':trans_ID  ,'product':product[ui_prod]['Name']  ,'price':product[ui_prod]['Price']  ,'Quantity':ui_quan  ,'gen_bill':(product[ui_prod]['Price']*ui_quan)-((product[ui_prod]['Price']*ui_quan)*product[ui_prod]['Discount'])/100}

# %%
Transaction
# Out:
# {'Quantity': 10,
#  'gen_bill': 30000.0,
#  'price': 4000,
#  'product': 'Elayachi',
#  'trans_ID': 68008.87481456719}

# %%
ts = json.dumps(Transaction)

# %%
ts = ts + '\n'

# %%
ts
# Out:
# '{"trans_ID": 68008.87481456719, "product": "Elayachi", "price": 4000, "Quantity": 10, "gen_bill": 30000.0}\n'

# %%
fd = open("sales.json",'w')

fd.write(ts)

fd.close()
